# %% [markdown]
# # Poojahira's version

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
plt.style.use("seaborn")

dir_path = os.path.abspath('')
os.chdir(dir_path)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Creation of files kdf5 for Flickr30k

# %%
os.remove('train_flickr.hdf5')
os.remove('val_flickr.hdf5')

# %%
# %run bottom-up_features/tsv.py
# Out:
# reading tsv...
# 31014it [11:35, 44.57it/s]
# done!

# %% [markdown]
# ### Create input files

# %%
# %run utils.py

create_input_files(dataset='flickr30k',
                       karpathy_json_path='data/caption_datasets/dataset_flickr30k.json',
                       captions_per_image=5,
                       min_word_freq=5,
                       output_folder='final_dataset_flickr',
                       max_len=50)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 21666/21666 [00:01<00:00, 15087.51it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 302/302 [00:00<00:00, 17192.34it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 293/293 [00:00<00:00, 13953.23it/s]

# %% [markdown]
# ### Training

# %%
import gc
import torch

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 20

# %%
# %run train.py
# Out:
# Using cuda
# Loading checkpoint and re-starting at epoch 2
# Epoch: [2][0/1084]	Batch Time 30.524 (30.524)	Data Load Time 20.140 (20.140)	Loss 155.7508 (155.7508)	Top-5 Accuracy 0.000 (0.000)
# Epoch: [2][500/1084]	Batch Time 2.908 (3.174)	Data Load Time 2.080 (2.269)	Loss 27.0235 (42.0056)	Top-5 Accuracy 39.241 (29.372)
# Epoch: [2][1000/1084]	Batch Time 2.486 (3.068)	Data Load Time 1.658 (2.178)	Loss 24.8475 (33.5508)	Top-5 Accuracy 43.871 (35.481)
# Validation: [0/16]	Batch Time 2.814 (2.814)	Loss 27.2650 (27.2650)	Top-5 Accuracy 48.083 (48.083)
#
#  * LOSS - 27.419, TOP-5 ACCURACY - 47.219, BLEU-4 - 0.0755
#
#
# Epochs since last improvement: 1
# C:\Users\ariane\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type DecoderWithAttention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\ariane\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Attention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\ariane\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\ariane\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\ariane\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Dropout. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\ariane\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Softmax. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\ariane\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Embedding. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\ariane\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LSTMCell. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch: [3][0/1084]	Batch Time 3.643 (3.643)	Data Load Time 2.768 (2.768)	Loss 21.9339 (21.9339)	Top-5 Accuracy 44.274 (44.274)
# Epoch: [3][500/1084]	Batch Time 3.579 (3.104)	Data Load Time 2.705 (2.219)	Loss 21.5795 (22.2185)	Top-5 Accuracy 47.640 (46.842)
# Epoch: [3][1000/1084]	Batch Time 2.786 (3.087)	Data Load Time 2.019 (2.206)	Loss 21.2167 (21.4249)	Top-5 Accuracy 46.973 (48.066)
# Validation: [0/16]	Batch Time 1.297 (1.297)	Loss 21.1680 (21.1680)	Top-5 Accuracy 53.664 (53.664)
#
#  * LOSS - 22.328, TOP-5 ACCURACY - 52.393, BLEU-4 - 0.1003
#
#
# Epochs since last improvement: 2
#
# Epoch: [4][0/1084]	Batch Time 3.233 (3.233)	Data Load Time 2.207 (2.207)	Loss 17.7418 (17.7418)	Top-5 Accuracy 50.076 (50.076)
# Epoch: [4][500/1084]	Batch Time 3.080 (3.190)	Data Load Time 2.251 (2.311)	Loss 19.7684 (19.1754)	Top-5 Accuracy 51.500 (51.749)
# Epoch: [4][1000/1084]	Batch Time 3.176 (3.142)	Data Load Time 2.425 (2.265)	Loss 18.9307 (18.8843)	Top-5 Accuracy 54.635 (52.459)
# Validation: [0/16]	Batch Time 1.173 (1.173)	Loss 20.4033 (20.4033)	Top-5 Accuracy 56.314 (56.314)
#
#  * LOSS - 19.511, TOP-5 ACCURACY - 55.714, BLEU-4 - 0.1119
#
#
# Epochs since last improvement: 3
#
# Epoch: [5][0/1084]	Batch Time 3.236 (3.236)	Data Load Time 2.126 (2.126)	Loss 19.7181 (19.7181)	Top-5 Accuracy 51.743 (51.743)
# Epoch: [5][500/1084]	Batch Time 2.737 (3.138)	Data Load Time 1.815 (2.269)	Loss 18.8761 (17.4888)	Top-5 Accuracy 54.519 (54.762)
# Epoch: [5][1000/1084]	Batch Time 3.081 (3.126)	Data Load Time 2.158 (2.249)	Loss 17.2881 (17.1410)	Top-5 Accuracy 54.945 (55.259)
# Validation: [0/16]	Batch Time 1.218 (1.218)	Loss 15.7107 (15.7107)	Top-5 Accuracy 60.209 (60.209)
#
#  * LOSS - 16.834, TOP-5 ACCURACY - 58.472, BLEU-4 - 0.1183
#
#
# Epochs since last improvement: 4
#
# Epoch: [6][0/1084]	Batch Time 3.111 (3.111)	Data Load Time 2.376 (2.376)	Loss 14.5299 (14.5299)	Top-5 Accuracy 57.862 (57.862)
# Epoch: [6][500/1084]	Batch Time 2.486 (3.148)	Data Load Time 1.673 (2.269)	Loss 13.4598 (16.1297)	Top-5 Accuracy 60.046 (56.880)
# Epoch: [6][1000/1084]	Batch Time 3.031 (3.113)	Data Load Time 2.242 (2.236)	Loss 13.3813 (15.8459)	Top-5 Accuracy 58.517 (57.254)
# Validation: [0/16]	Batch Time 1.125 (1.125)	Loss 15.7426 (15.7426)	Top-5 Accuracy 58.369 (58.369)
#
#  * LOSS - 14.896, TOP-5 ACCURACY - 59.824, BLEU-4 - 0.1304
#
#
# Epochs since last improvement: 5
#
# Epoch: [7][0/1084]	Batch Time 3.271 (3.271)	Data Load Time 2.428 (2.428)	Loss 15.1970 (15.1970)	Top-5 Accuracy 59.097 (59.097)
# Epoch: [7][500/1084]	Batch Time 2.923 (3.125)	Data Load Time 2.001 (2.252)	Loss 16.5316 (14.9896)	Top-5 Accuracy 58.430 (58.523)
# Epoch: [7][1000/1084]	Batch Time 3.284 (3.107)	Data Load Time 2.236 (2.228)	Loss 15.5518 (14.8008)	Top-5 Accuracy 55.827 (58.797)
# Validation: [0/16]	Batch Time 1.626 (1.626)	Loss 13.6226 (13.6226)	Top-5 Accuracy 58.423 (58.423)
#
#  * LOSS - 14.016, TOP-5 ACCURACY - 61.062, BLEU-4 - 0.1273
#
#
# Epochs since last improvement: 6
#
# Epoch: [8][0/1084]	Batch Time 3.676 (3.676)	Data Load Time 2.770 (2.770)	Loss 14.8987 (14.8987)	Top-5 Accuracy 59.515 (59.515)
# Epoch: [8][500/1084]	Batch Time 2.957 (3.124)	Data Load Time 2.113 (2.242)	Loss 13.1891 (14.1792)	Top-5 Accuracy 60.952 (59.856)
# Epoch: [8][1000/1084]	Batch Time 2.862 (3.095)	Data Load Time 1.953 (2.217)	Loss 12.7339 (14.0222)	Top-5 Accuracy 61.337 (60.089)
# Validation: [0/16]	Batch Time 1.063 (1.063)	Loss 12.6757 (12.6757)	Top-5 Accuracy 61.839 (61.839)
#
#  * LOSS - 13.142, TOP-5 ACCURACY - 61.877, BLEU-4 - 0.137
#
#
# Epochs since last improvement: 7
#
# Epoch: [9][0/1084]	Batch Time 3.598 (3.598)	Data Load Time 2.597 (2.597)	Loss 13.3480 (13.3480)	Top-5 Accuracy 61.155 (61.155)
# Epoch: [9][500/1084]	Batch Time 2.708 (3.096)	Data Load Time 1.911 (2.216)	Loss 15.1019 (13.4956)	Top-5 Accuracy 58.160 (60.929)
# Epoch: [9][1000/1084]	Batch Time 2.363 (3.075)	Data Load Time 1.564 (2.196)	Loss 12.5017 (13.4105)	Top-5 Accuracy 61.579 (61.116)
# Validation: [0/16]	Batch Time 1.189 (1.189)	Loss 16.2234 (16.2234)	Top-5 Accuracy 61.181 (61.181)
#
#  * LOSS - 12.715, TOP-5 ACCURACY - 62.692, BLEU-4 - 0.1378
#
#
# Epochs since last improvement: 8
#
#
# DECAYING learning rate.
# The new learning rate is 0.001600
#
# Epoch: [10][0/1084]	Batch Time 3.311 (3.311)	Data Load Time 2.323 (2.323)	Loss 12.8728 (12.8728)	Top-5 Accuracy 62.221 (62.221)
# Epoch: [10][500/1084]	Batch Time 3.066 (3.061)	Data Load Time 2.314 (2.186)	Loss 13.5448 (12.9942)	Top-5 Accuracy 59.287 (62.111)
# Epoch: [10][1000/1084]	Batch Time 2.720 (2.935)	Data Load Time 1.922 (2.062)	Loss 12.3387 (12.9247)	Top-5 Accuracy 64.811 (62.208)
# Validation: [0/16]	Batch Time 1.458 (1.458)	Loss 13.2643 (13.2643)	Top-5 Accuracy 66.692 (66.692)
#
#  * LOSS - 12.481, TOP-5 ACCURACY - 63.373, BLEU-4 - 0.1361
#
#
# Epochs since last improvement: 9
#
# Epoch: [11][0/1084]	Batch Time 3.083 (3.083)	Data Load Time 2.173 (2.173)	Loss 11.2827 (11.2827)	Top-5 Accuracy 66.395 (66.395)
# Epoch: [11][500/1084]	Batch Time 2.908 (2.901)	Data Load Time 2.048 (2.021)	Loss 10.5776 (12.7451)	Top-5 Accuracy 65.155 (62.836)
# Epoch: [11][1000/1084]	Batch Time 2.509 (2.848)	Data Load Time 1.736 (1.976)	Loss 13.2276 (12.6616)	Top-5 Accuracy 62.725 (62.949)
# Validation: [0/16]	Batch Time 1.422 (1.422)	Loss 12.4879 (12.4879)	Top-5 Accuracy 62.725 (62.725)
#
#  * LOSS - 12.220, TOP-5 ACCURACY - 63.800, BLEU-4 - 0.1417
#
#
# Epochs since last improvement: 10
#
# Epoch: [12][0/1084]	Batch Time 3.084 (3.084)	Data Load Time 2.047 (2.047)	Loss 13.5882 (13.5882)	Top-5 Accuracy 62.545 (62.545)
# Epoch: [12][500/1084]	Batch Time 2.783 (2.795)	Data Load Time 1.908 (1.926)	Loss 14.1317 (12.4613)	Top-5 Accuracy 60.549 (63.564)
# Epoch: [12][1000/1084]	Batch Time 2.565 (2.749)	Data Load Time 1.689 (1.884)	Loss 12.4619 (12.4397)	Top-5 Accuracy 62.199 (63.591)
# Validation: [0/16]	Batch Time 1.297 (1.297)	Loss 13.7603 (13.7603)	Top-5 Accuracy 62.095 (62.095)
#
#  * LOSS - 12.139, TOP-5 ACCURACY - 64.412, BLEU-4 - 0.1454
#
#
# Epochs since last improvement: 11
#
# Epoch: [13][0/1084]	Batch Time 2.925 (2.925)	Data Load Time 2.126 (2.126)	Loss 12.3680 (12.3680)	Top-5 Accuracy 62.540 (62.540)
# Epoch: [13][500/1084]	Batch Time 2.941 (2.927)	Data Load Time 2.205 (2.045)	Loss 12.3546 (12.3207)	Top-5 Accuracy 64.193 (64.236)
# Epoch: [13][1000/1084]	Batch Time 3.142 (2.983)	Data Load Time 2.189 (2.082)	Loss 10.6087 (12.2523)	Top-5 Accuracy 64.993 (64.242)
# Validation: [0/16]	Batch Time 1.516 (1.516)	Loss 15.3297 (15.3297)	Top-5 Accuracy 63.802 (63.802)
#
#  * LOSS - 12.168, TOP-5 ACCURACY - 64.809, BLEU-4 - 0.1494
#
#
# Epochs since last improvement: 12
#
# Epoch: [14][0/1084]	Batch Time 3.144 (3.144)	Data Load Time 2.189 (2.189)	Loss 13.0488 (13.0488)	Top-5 Accuracy 66.288 (66.288)
# Epoch: [14][500/1084]	Batch Time 2.909 (3.017)	Data Load Time 1.940 (2.090)	Loss 11.9491 (12.1786)	Top-5 Accuracy 64.746 (64.670)
# Epoch: [14][1000/1084]	Batch Time 2.926 (2.914)	Data Load Time 2.034 (2.019)	Loss 12.0944 (12.1084)	Top-5 Accuracy 64.388 (64.822)
# Validation: [0/16]	Batch Time 1.125 (1.125)	Loss 12.9688 (12.9688)	Top-5 Accuracy 65.000 (65.000)
#
#  * LOSS - 11.838, TOP-5 ACCURACY - 65.287, BLEU-4 - 0.1455
#
#
# Epochs since last improvement: 13
#
# Epoch: [15][0/1084]	Batch Time 2.923 (2.923)	Data Load Time 2.172 (2.172)	Loss 11.2593 (11.2593)	Top-5 Accuracy 66.950 (66.950)
# Epoch: [15][500/1084]	Batch Time 2.770 (2.844)	Data Load Time 1.987 (1.971)	Loss 10.4815 (11.9003)	Top-5 Accuracy 64.769 (65.412)
# Epoch: [15][1000/1084]	Batch Time 2.923 (2.855)	Data Load Time 2.047 (1.972)	Loss 9.5149 (11.9656)	Top-5 Accuracy 66.770 (65.350)
# Validation: [0/16]	Batch Time 1.359 (1.359)	Loss 11.2305 (11.2305)	Top-5 Accuracy 65.634 (65.634)
#
#  * LOSS - 11.918, TOP-5 ACCURACY - 65.560, BLEU-4 - 0.1499
#
#
# Epochs since last improvement: 14
#
# Epoch: [16][0/1084]	Batch Time 3.719 (3.719)	Data Load Time 2.705 (2.705)	Loss 11.3007 (11.3007)	Top-5 Accuracy 67.312 (67.312)
# Epoch: [16][500/1084]	Batch Time 3.190 (3.076)	Data Load Time 2.251 (2.143)	Loss 13.0602 (11.8308)	Top-5 Accuracy 64.112 (65.872)
# Epoch: [16][1000/1084]	Batch Time 2.565 (2.966)	Data Load Time 1.769 (2.052)	Loss 10.8592 (11.8611)	Top-5 Accuracy 67.347 (65.859)
# Validation: [0/16]	Batch Time 1.437 (1.437)	Loss 11.5147 (11.5147)	Top-5 Accuracy 66.119 (66.119)
#
#  * LOSS - 11.927, TOP-5 ACCURACY - 65.878, BLEU-4 - 0.1522
#
#
# Epochs since last improvement: 15
# Epoch: [17][0/1084]	Batch Time 2.641 (2.641)	Data Load Time 1.922 (1.922)	Loss 10.7827 (10.7827)	Top-5 Accuracy 66.881 (66.881)
# Epoch: [17][500/1084]	Batch Time 2.615 (2.907)	Data Load Time 1.786 (2.034)	Loss 11.5275 (11.8212)	Top-5 Accuracy 65.234 (66.090)
# Epoch: [17][1000/1084]	Batch Time 2.345 (2.871)	Data Load Time 1.486 (1.996)	Loss 10.0484 (11.7747)	Top-5 Accuracy 65.030 (66.229)
# Validation: [0/16]	Batch Time 0.987 (0.987)	Loss 11.9001 (11.9001)	Top-5 Accuracy 66.178 (66.178)
#
#  * LOSS - 11.703, TOP-5 ACCURACY - 66.132, BLEU-4 - 0.155
#
#
# Epochs since last improvement: 16
#
#
# DECAYING learning rate.
# The new learning rate is 0.001280
#
# Epoch: [18][0/1084]	Batch Time 3.157 (3.157)	Data Load Time 2.250 (2.250)	Loss 10.5470 (10.5470)	Top-5 Accuracy 66.843 (66.843)
# Epoch: [18][500/1084]	Batch Time 2.438 (2.923)	Data Load Time 1.766 (2.053)	Loss 9.5152 (11.6950)	Top-5 Accuracy 69.249 (66.683)
# Epoch: [18][1000/1084]	Batch Time 2.888 (2.896)	Data Load Time 2.154 (2.024)	Loss 13.0032 (11.6772)	Top-5 Accuracy 63.789 (66.791)
# Validation: [0/16]	Batch Time 1.422 (1.422)	Loss 11.8091 (11.8091)	Top-5 Accuracy 64.575 (64.575)
#
#  * LOSS - 11.904, TOP-5 ACCURACY - 66.315, BLEU-4 - 0.1534
#
#
# Epochs since last improvement: 17
#
# Epoch: [19][0/1084]	Batch Time 3.190 (3.190)	Data Load Time 2.298 (2.298)	Loss 11.7703 (11.7703)	Top-5 Accuracy 65.481 (65.481)
# Epoch: [19][500/1084]	Batch Time 3.520 (2.932)	Data Load Time 2.503 (2.058)	Loss 10.7900 (11.6244)	Top-5 Accuracy 68.477 (67.150)
# Epoch: [19][1000/1084]	Batch Time 2.953 (2.922)	Data Load Time 2.172 (2.048)	Loss 11.5583 (11.6190)	Top-5 Accuracy 68.298 (67.134)
# Validation: [0/16]	Batch Time 1.298 (1.298)	Loss 11.1352 (11.1352)	Top-5 Accuracy 67.740 (67.740)
#
#  * LOSS - 11.908, TOP-5 ACCURACY - 66.629, BLEU-4 - 0.1577
#
#
# Epochs since last improvement: 18
#
# Epoch: [20][0/1084]	Batch Time 3.269 (3.269)	Data Load Time 2.251 (2.251)	Loss 12.2151 (12.2151)	Top-5 Accuracy 67.627 (67.627)
# Epoch: [20][500/1084]	Batch Time 3.078 (2.998)	Data Load Time 2.125 (2.119)	Loss 14.0319 (11.6299)	Top-5 Accuracy 64.931 (67.468)
# Epoch: [20][1000/1084]	Batch Time 3.142 (3.020)	Data Load Time 2.470 (2.140)	Loss 9.6313 (11.5497)	Top-5 Accuracy 68.709 (67.506)
# Validation: [0/16]	Batch Time 1.203 (1.203)	Loss 10.5900 (10.5900)	Top-5 Accuracy 67.618 (67.618)
#
#  * LOSS - 11.695, TOP-5 ACCURACY - 66.718, BLEU-4 - 0.1589
#
#
# Epochs since last improvement: 19
#
# Epoch: [21][0/1084]	Batch Time 3.222 (3.222)	Data Load Time 2.347 (2.347)	Loss 11.7919 (11.7919)	Top-5 Accuracy 66.951 (66.951)
# Epoch: [21][500/1084]	Batch Time 4.115 (3.563)	Data Load Time 3.240 (2.656)	Loss 10.8191 (11.5064)	Top-5 Accuracy 65.379 (67.814)
# Epoch: [21][1000/1084]	Batch Time 3.378 (4.334)	Data Load Time 2.284 (3.423)	Loss 12.3057 (11.5162)	Top-5 Accuracy 67.790 (67.756)
# Validation: [0/16]	Batch Time 1.156 (1.156)	Loss 11.0642 (11.0642)	Top-5 Accuracy 68.530 (68.530)
#
#  * LOSS - 11.699, TOP-5 ACCURACY - 66.574, BLEU-4 - 0.156
#
#
# Epochs since last improvement: 20

# %% [markdown]
# ### Plotting the metrics obtained during training

# %% [markdown]
# #### With the COCO dataset (First 2 epochs)

# %%
# 12 scores =1 epoch
losses_train_coco = [79.5072,33.3733,29.2574,27.1445,24.9402,13.3282,12.6251,12.6628,12.1809,13.1595,12.5314,10.9447,\
                     12.0483,10.8319,11.1864,9.8083,15.1406,10.5921,9.8913,10.1091,9.3261,9.3010,9.2150,9.4022]
TOP5_train_coco = [0,42.62,42.97,53.78,56.70,58.80,59.98,61.31,62.08,60.26,62.01,64.91,63.06,63.19,64.71,67.48,61.92,\
                  65.25,67.58,67.85,64.86,69.39,68.69,67.62]

# 1 score =1 epoch
losses_val_coco = [11.089,9.102]
TOP5_val_coco = [62.253,70.017]
bleu4_coco = [0.1586,0.1865]

# %% [markdown]
# #### With the Flickr30k dataset

# %%
# 3 scores =1 epoch
losses_train=[55.7508,27.0235,24.8475,21.9339,21.5795,21.2167,17.7418,19.7684,18.9307,19.7181,18.8761,17.2881,\
              14.5299,16.1297,15.8459,15.1970,14.9896,14.8008,14.8987,14.1792,14.0222,13.3480,13.4956,13.4105,\
             12.8728,12.9942,12.9247,11.2827,12.7451,12.6616,13.5882,12.4613,12.4397,12.3680,12.3207,12.2523,\
             13.0488,12.1786,12.1084,11.2593,11.9003,11.9656,11.3007,11.8308,11.8611,10.7827,11.8212,11.7747,\
             10.5470,11.6950,11.6772,11.7703,11.6244,11.6190,12.2151,11.6299,11.5497,11.7919,11.5064,11.5162]
TOP5_train=[0,39.241,43.871,44.274,47.640,46.973,50.076,51.5,54.635,51.743,54.519,54.945,57.862,60.046,58.517,\
           59.097,58.523,58.797,59.515,59.856,60.089,61.155,60.929,61.116,62.221,62.111,62.208,66.395,62.836,\
           62.949,62.545,63.564,63.591,62.54,64.236,64.242,66.288,64.670,64.822,66.950,65.412,65.350,67.312,\
           65.872,65.859,66.881,66.0924,66.229,66.843,66.683,66.791,65.481,67.150,67.134,67.627,67.468,67.506,\
           66.951,67.814,67.756]

# 1 score =1 epoch
losses_val=[27.419,22.328,19.511,16.834,14.896,14.016,13.142,12.715,12.481,12.22,12.139,12.168,11.838,11.918,11.927,\
           11.703,11.904,11.908,11.695,11.699]
TOP5_val=[47.219,52.393,55.714,58.472,59.824,61.062,61.877,62.692,63.373,63.8,64.412,64.809,65.287,65.560,65.878,\
         66.132,66.315,66.629,66.718,66.574]
bleu4=[0.0755,0.1003,0.1119,0.1183,0.1304,0.1273,0.137,0.1378,0.1361,0.1417,0.1454,0.1494,0.1455,0.1499,0.1522,\
      0.155,0.1534,0.1577,0.1589,0.156]

# %%
# Ranges to match the batches and epochs (3 batches hence loss_train result per epoch)
n_epochs_coco=2
n_epochs_flickr=20

epochs=np.arange(1,n_epochs_coco+n_epochs_flickr+1)
batches= list(np.arange(1,12*n_epochs_coco+1)/12) + list(np.arange(1+3*n_epochs_coco,3*n_epochs_flickr+1+3*n_epochs_coco)/3)

# %% [markdown]
# #### Loss

# %%
plt.figure(figsize=(10,7))
plt.title("Evolution of the loss",fontsize=16)

plt.plot(batches,losses_train_coco+losses_train,alpha=0.7,label="Training")
plt.plot(epochs,losses_val_coco+losses_val,color='orange',label="Validation")


# Line to separate when we switched from COCO to Flickr30k + annotations
plt.axvspan(0, 2, alpha=0.1, color='red')
plt.axvspan(2, max(epochs), alpha=0.1, color='green')
plt.annotate('On COCO dataset', xy =(0, 0.99*np.max(losses_train_coco)), xycoords='data',\
             bbox =dict(boxstyle="square,pad=0.5", ec=(1., 1., 1.),fc=(0.8, 0.5, 0.5),alpha=0.7))
plt.annotate('On Flickr30k dataset', xy =(10, 0.99*np.max(losses_train_coco)), xycoords='data',\
             bbox =dict(boxstyle="square,pad=0.5", ec=(1., 1., 1.),fc=(0.5, 0.8, 0.5),alpha=0.5))


# Set axis
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.axes().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.axes().set(xlim=(-0.5, max(epochs)+0.5))

plt.legend()
plt.show()
# Out:
# c:\users\alixa\appdata\local\programs\python\python35\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# #### TOP-5 accuracy metric

# %%
plt.figure(figsize=(10,7))
plt.title("Evolution of the TOP-5 accuracy metric",fontsize=16)

plt.plot(batches,TOP5_train_coco+TOP5_train,alpha=0.7,label="Training")
plt.plot(epochs,TOP5_val_coco+TOP5_val,color='orange',label="Validation")


# Line to separate when we switched from COCO to Flickr30k + annotations
plt.axvspan(0, 2, alpha=0.1, color='red')
plt.axvspan(2, max(epochs), alpha=0.1, color='green')
plt.annotate('On COCO dataset', xy =(0, 0.99*np.max(TOP5_train_coco)), xycoords='data',\
             bbox =dict(boxstyle="square,pad=0.5", ec=(1., 1., 1.),fc=(0.8, 0.5, 0.5),alpha=0.7))
plt.annotate('On Flickr30k dataset', xy =(10, 0.99*np.max(TOP5_train_coco)), xycoords='data',\
             bbox =dict(boxstyle="square,pad=0.5", ec=(1., 1., 1.),fc=(0.5, 0.8, 0.5),alpha=0.5))


# Set axis
plt.ylabel("TOP-5 accuracy")
plt.xlabel("Epoch")
plt.axes().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.axes().set(xlim=(-0.5, max(epochs)+0.5))

plt.legend()
plt.show()
# Out:
# c:\users\alixa\appdata\local\programs\python\python35\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# #### BLEU-4 metric

# %%
plt.figure(figsize=(10,7))
plt.title("Evolution of the BLEU-4 metric",fontsize=16)

plt.plot(epochs,bleu4_coco+bleu4,color='orange',label="Validation")


# Line to separate when we switched from COCO to Flickr30k + annotations
plt.axvspan(0, 2, alpha=0.1, color='red')
plt.axvspan(2, max(epochs), alpha=0.1, color='green')
plt.annotate('On COCO dataset', xy =(0, 0.99*np.max(bleu4_coco)), xycoords='data',\
             bbox =dict(boxstyle="square,pad=0.5", ec=(1., 1., 1.),fc=(0.8, 0.5, 0.5),alpha=0.7))
plt.annotate('On Flickr30k dataset', xy =(10, 0.99*np.max(bleu4_coco)), xycoords='data',\
             bbox =dict(boxstyle="square,pad=0.5", ec=(1., 1., 1.),fc=(0.5, 0.8, 0.5),alpha=0.5))


plt.ylabel("BLEU-4 score")
plt.xlabel("Epoch")
plt.axes().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.axes().set(xlim=(-0.5, max(epochs)+0.5))

plt.legend()
plt.show()
# Out:
# c:\users\alixa\appdata\local\programs\python\python35\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# %run eval.py
# Out:
# EVALUATING AT BEAM SIZE 5: 100%|██████████| 1465/1465 [1:08:28<00:00,  2.80s/it]
# {'CIDEr': 0.5243185889017987, 'Bleu_4': 0.24540300612681126, 'ROUGE_L': 0.4747543760696306, 'Bleu_1': 0.6485461441213244, 'Bleu_3': 0.3460391533900509, 'Bleu_2': 0.4818927604631453}

# %% [markdown]
# {'CIDEr': 0.5243185889017987, 'Bleu_4': 0.24540300612681126, 'ROUGE_L': 0.4747543760696306, 'Bleu_1': 0.6485461441213244, 'Bleu_3': 0.3460391533900509, 'Bleu_2': 0.4818927604631453}

# %% [markdown]
# ### Display some results obtained on validation dataset

# %%
# %run display_results.py
# Out:
# Predicted caption: a man wearing a hat and a hat
# Reference captions: - the man with pierced ears is wearing glasses and an orange hat
#                     - a man with glasses is wearing a beer can <unk> hat
#                     - a man with glasses is wearing a beer can <unk> hat
#                     - a man with glasses is wearing a beer can <unk> hat
#                     - a man with glasses is wearing a beer can <unk> hat
# Predicted caption: a brown and white dog is running through the grass
# Reference captions: - a dog runs on the green grass near a wooden fence
#                     - a boston terrier is running on lush green grass in front of a white fence
#                     - a boston terrier is running on lush green grass in front of a white fence
#                     - a boston terrier is running on lush green grass in front of a white fence
#                     - a boston terrier is running on lush green grass in front of a white fence
# Predicted caption: a girl in a white uniform is playing a martial arts
# Reference captions: - a girl breaking boards by using karate
#                     - a girl kicking a stick that a man is holding in <unk> <unk> do class
#                     - a girl kicking a stick that a man is holding in <unk> <unk> do class
#                     - a girl kicking a stick that a man is holding in <unk> <unk> do class
#                     - a girl kicking a stick that a man is holding in <unk> <unk> do class
# Predicted caption: a group of people are standing in the snow
# Reference captions: - five snowmobile riders all wearing helmets and goggles line up in a snowy clearing in a forest in front of their snowmobiles they are all wearing black snow pants and from left to right they are wearing a black coat white coat red coat blue coat and black coat
#                     - five people wearing winter clothing helmets and ski goggles stand outside in the snow
#                     - five people wearing winter clothing helmets and ski goggles stand outside in the snow
#                     - five people wearing winter clothing helmets and ski goggles stand outside in the snow
#                     - five people wearing winter clothing helmets and ski goggles stand outside in the snow
# Predicted caption: two men are working on a roof
# Reference captions: - people are fixing the roof of a house
#                     - two men sitting on the roof of a house while another one stands on a ladder
#                     - two men sitting on the roof of a house while another one stands on a ladder
#                     - two men sitting on the roof of a house while another one stands on a ladder
#                     - two men sitting on the roof of a house while another one stands on a ladder
# Predicted caption: a man in a white shirt is taking a picture
# Reference captions: - man taking a photograph of a well dressed group of teens
#                     - a bride in a light pink dress poses for a picture with male <unk> and is being photographed by a man in a cream shirt with white pants
#                     - a bride in a light pink dress poses for a picture with male <unk> and is being photographed by a man in a cream shirt with white pants
#                     - a bride in a light pink dress poses for a picture with male <unk> and is being photographed by a man in a cream shirt with white pants
#                     - a bride in a light pink dress poses for a picture with male <unk> and is being photographed by a man in a cream shirt with white pants
# {'Bleu_4': 0.4455723013163596, 'CIDEr': 1.1645838763903194, 'ROUGE_L': 0.6680197197639302, 'Bleu_2': 0.658674396065929, 'Bleu_1': 0.8088693501266748, 'Bleu_3': 0.5369810614321533}
